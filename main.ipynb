# %%
# %run func_data_to_vectors.ipynb
# %run lagrange_function_solution.ipynb
# %run projection_of_vectors_on_plane.ipynb
# %run draw_all.ipynb
# Out:
# [0. 0. 1.]
# 1.000000000000

# %%
draw_all_accelerometer()
# Out:
# <div>
#
#
#             <div id="20be8796-cf03-4849-acea-ce7b91802e7d" class="plotly-graph-div" style="height:525px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("20be8796-cf03-4849-acea-ce7b91802e7d")) {
#                     Plotly.newPlot(
#                         '20be8796-cf03-4849-acea-ce7b91802e7d',
# ...

# %%
draw_all_gyroscope()
# Out:
# <div>
#
#
#             <div id="7730f36a-486f-4baf-894e-6f876672da72" class="plotly-graph-div" style="height:525px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7730f36a-486f-4baf-894e-6f876672da72")) {
#                     Plotly.newPlot(
#                         '7730f36a-486f-4baf-894e-6f876672da72',
# ...
