# %%
# %run func_data_to_vectors.ipynb
# %run ArtyomSvsn.ipynb
# %run 1CFarkhat.ipynb
# %run draw_all.ipynb
# Out:
# [1.87005352e-06 0.00000000e+00 1.00000000e+00]
# 1.000000000003
# ...

# %%
draw_all()
# Out:
# <div>
#
#
#             <div id="667ff599-f2fe-4ab8-af7d-558ded93d1ee" class="plotly-graph-div" style="height:525px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("667ff599-f2fe-4ab8-af7d-558ded93d1ee")) {
#                     Plotly.newPlot(
#                         '667ff599-f2fe-4ab8-af7d-558ded93d1ee',
# ...
