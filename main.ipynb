# %%
# %run func_data_to_vectors.ipynb
# %run ArtyomSvsn.ipynb
# %run 1CFarkhat.ipynb
# %run draw_all.ipynb
# Out:
# [0.00000000e+00 1.80229536e-05 1.00000000e+00]
# 1.000000000325
# ...

# %%
draw_all()
# Out:
# <div>
#
#
#             <div id="5177d015-80be-4e5a-bb3e-31bb99821de9" class="plotly-graph-div" style="height:525px; width:700px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5177d015-80be-4e5a-bb3e-31bb99821de9")) {
#                     Plotly.newPlot(
#                         '5177d015-80be-4e5a-bb3e-31bb99821de9',
# ...
