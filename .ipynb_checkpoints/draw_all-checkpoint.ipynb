# %%
import plotly.graph_objects as go

size_of_cube = 5
size_of_cube_gyroscope = 3

def draw_all_accelerometer():
    x = []
    y = []
    z = []
    for el in vectors_accelerometer:
        x.append(el[0])
        y.append(el[1])
        z.append(el[2])

    fig = go.Figure(data=[
        go.Scatter3d(x=x, y=y, z=z, opacity=0.5, name='data in 3D')
    ])

    fig.update_layout(
        scene = dict(xaxis = dict(nticks=4, range=[-size_of_cube,size_of_cube],),
                     yaxis = dict(nticks=4, range=[-size_of_cube,size_of_cube],),
                     zaxis = dict(nticks=4, range=[-size_of_cube,size_of_cube],),),
        width=700,
        margin=dict(r=20, l=10, b=10, t=10))

    fig.show()

    x = []
    y = []
    z = []
    for el in plane_vectors_accelerometer:
        x.append(el[0])
        y.append(el[1])
        z.append(el[2])

    fig = go.Figure(data=[
        go.Scatter3d(x=x, y=y, z=z, opacity=0.5, name='data in 3D')
    ])

    fig.update_layout(
        scene = dict(xaxis = dict(nticks=4, range=[-size_of_cube,size_of_cube],),
                     yaxis = dict(nticks=4, range=[-size_of_cube,size_of_cube],),
                     zaxis = dict(nticks=4, range=[-size_of_cube,size_of_cube],),),
        width=700,
        margin=dict(r=20, l=10, b=10, t=10))

    fig.show()




def draw_all_gyroscope():
    x = []
    y = []
    z = []
    for el in vectors_gyroscope:
        x.append(el[0])
        y.append(el[1])
        z.append(el[2])

    fig = go.Figure(data=[
        go.Scatter3d(x=x, y=y, z=z, opacity=0.5, name='data in 3D')
    ])

    fig.update_layout(
        scene = dict(xaxis = dict(nticks=4, range=[-size_of_cube_gyroscope,size_of_cube_gyroscope],),
                     yaxis = dict(nticks=4, range=[-size_of_cube_gyroscope,size_of_cube_gyroscope],),
                     zaxis = dict(nticks=4, range=[-size_of_cube_gyroscope,size_of_cube_gyroscope],),),
        width=700,
        margin=dict(r=20, l=10, b=10, t=10))

    fig.show()


    x = []
    y = []
    z = []
    for el in plane_vectors_gyroscope:
        x.append(el[0])
        y.append(el[1])
        z.append(el[2])

    fig = go.Figure(data=[
        go.Scatter3d(x=x, y=y, z=z, opacity=0.5, name='data in 3D')
    ])

    fig.update_layout(
        scene = dict(xaxis = dict(nticks=4, range=[-size_of_cube_gyroscope,size_of_cube_gyroscope],),
                     yaxis = dict(nticks=4, range=[-size_of_cube_gyroscope,size_of_cube_gyroscope],),
                     zaxis = dict(nticks=4, range=[-size_of_cube_gyroscope,size_of_cube_gyroscope],),),
        width=700,
        margin=dict(r=20, l=10, b=10, t=10))

    fig.show()
